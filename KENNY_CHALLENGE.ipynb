# %% [markdown]
# <a href="https://colab.research.google.com/github/Uche002/My-SQL-PORTFOLIO-PROJECT-1/blob/main/KENNY_CHALLENGE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('EDO.csv')
df
# Out:
#                Timestamp  battery voltage(V)  inverter voltage(V)  \
# 0    2021-08-01 23:58:45                51.2                219.8
# 1    2021-08-01 23:54:26                51.2                219.8
# 2    2021-08-01 23:49:34                51.2                219.8
# 3    2021-08-01 23:44:42                51.2                219.8
# 4    2021-08-01 23:39:15                51.2                219.8
# ..                   ...                 ...                  ...
# 281  2021-08-01 00:22:06                50.9                219.8
# 282  2021-08-01 00:17:13                50.9                219.8
# 283  2021-08-01 00:12:20                50.9                219.8
# 284  2021-08-01 00:07:28                50.9                219.8
# 285  2021-08-01 00:02:03                51.0                219.8
#
#      grid voltage(V)  inverter current(A)  grid current(A)  load current(A)  \
# 0                0.0                  1.7              0.0              0.3
# ...

# %%
pivot = df.pivot_table(index=['Timestamp'], values=['battery voltage(V)','PLoad(W)','charger power(W)'])

print (pivot)
# Out:
#                      PLoad(W)  battery voltage(V)  charger power(W)
# Timestamp
# 2021-08-01 00:02:03         0                51.0               0.0
# 2021-08-01 00:07:28         0                50.9               0.0
# 2021-08-01 00:12:20         0                50.9               0.0
# 2021-08-01 00:17:13         0                50.9               0.0
# 2021-08-01 00:22:06         0                50.9               0.0
# ...                       ...                 ...               ...
# 2021-08-01 23:39:15         0                51.2               0.0
# 2021-08-01 23:44:42         0                51.2               0.0
# 2021-08-01 23:49:34         0                51.2               0.0
# 2021-08-01 23:54:26         0                51.2               0.0
# 2021-08-01 23:58:45         0                51.2               0.0
#
# [286 rows x 3 columns]

# %%
df.dtypes
# Out:
# Timestamp                           object
# battery voltage(V)                 float64
# inverter voltage(V)                float64
# grid voltage(V)                    float64
# inverter current(A)                float64
# grid current(A)                    float64
# load current(A)                    float64
# PGrid(W)                             int64
# PLoad(W)                             int64
# accumulated buy power(kWh)           int64
# accumulated sell power(kWh)          int64
# accumulated load power(kWh)          int64
# accumulated self_use power(kWh)      int64
# batt power(W)                        int64
# PV voltage(V)                      float64
# charger current(A)                 float64
# charger power(W)                   float64
# accumulated power(kWh)               int64
# dtype: object

# %%
df['Timestamp'] = pd.to_datetime(df.Timestamp)

# %%
df.dtypes
# Out:
# Timestamp                          datetime64[ns]
# battery voltage(V)                        float64
# inverter voltage(V)                       float64
# grid voltage(V)                           float64
# inverter current(A)                       float64
# grid current(A)                           float64
# load current(A)                           float64
# PGrid(W)                                    int64
# PLoad(W)                                    int64
# accumulated buy power(kWh)                  int64
# accumulated sell power(kWh)                 int64
# accumulated load power(kWh)                 int64
# accumulated self_use power(kWh)             int64
# batt power(W)                               int64
# PV voltage(V)                             float64
# charger current(A)                        float64
# charger power(W)                          float64
# accumulated power(kWh)                      int64
# dtype: object

# %%
df.Timestamp.dt.hour
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4088bef2cb2e> in <module>()
# ----> 1 df.Timestamp.dt.hour
#
# NameError: name 'df' is not defined
